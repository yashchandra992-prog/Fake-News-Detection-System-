# %% [markdown]
# <a href="https://colab.research.google.com/github/yashchandra992-prog/Fake-News-Detection-System-/blob/main/FAKE_NEWS_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2c17abe-9b01-4881-9465-0aea6ec42bb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2c17abe-9b01-4881-9465-0aea6ec42bb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("fake_news_dataset_100.csv")

# %%
data.head()
# Out:
#                                           News Label
# 0    India launches new satellite successfully  Real
# 1    Government announces new education policy  Real
# 2  Heavy rainfall expected in Mumbai this week  Real
# 3      ISRO completes successful rocket launch  Real
# 4                New metro line opens in Delhi  Real

# %%
data.shape
# Out:
# (100, 2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = data["News"]
y = data["Label"]

# %%
vectorizer = TfidfVectorizer()
x = vectorizer.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
x,
y,
test_size=0.3,
random_state=42,
stratify=y
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,prediction)

print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.8666666666666667

# %%
news = ["Government launches a new education policy"]
news_vector = vectorizer.transform(news)

print(model.predict(news_vector))
# Out:
# ['Real']

# %%
news = ["Aliens have opened a shopping mall in Delhi"]
news_vector = vectorizer.transform(news)

print(model.predict(news_vector))
# Out:
# ['Fake']
